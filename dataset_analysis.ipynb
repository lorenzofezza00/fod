# %% [markdown]
# # Faulty Output Dataset

# %% [markdown]
# Download the dataset from [Google Drive](https://drive.google.com/file/d/18IpnsJsNgoVc8_Ii94oiQSd5sP07GTpH/view?usp=sharing) and unzip it with the following code

# %%
# !unzip ./faulty_output_dataset.zip
# Out:
# Archive:  ./faulty_output_dataset.zip
# replace faulty_output_dataset/c/fm0_479_595.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# ## Imports

# %%
# Dataloader
from fod_data_loader import get_fod_dataset

# Color Pallete
from utils import get_color_pallete, load_faults, filter_faults, cityscapes_labels_dict

# Dataset statistics visualization
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
import ipywidgets as widgets
from ipywidgets import VBox, interactive_output

# %%
fod_dataset = get_fod_dataset('FOD', root='./faulty_output_dataset')
# Out:
# Found 68001 masks in the folder ./faulty_output_dataset

# %%
n = len(fod_dataset)
print(n)
# Out:
# 68001

# %% [markdown]
# ## FOD entry example

# %%
frame, fault, mIoU, pa, cmask, fmask, label = fod_dataset[3]

fig = plt.figure(figsize=(16, 32))
columns = 2
rows = 1
fig.add_subplot(rows, columns, 1)
plt.imshow(get_color_pallete(cmask.cpu().numpy()))
plt.axis('off')
fig.add_subplot(rows, columns, 2)
plt.imshow(get_color_pallete(fmask.cpu().numpy()))
plt.axis('off')
plt.show()

# %% [markdown]
# ## CSV data

# %%
df = pd.read_csv('./faulty_output_dataset/faulty_output_dataset.csv')
labels = df['Label'].astype(int)
ids = df[['Frame', 'Injection']]
masks_ids = ids

# %%
# def compute_class_frequencies(mask):
#     frequencies = np.bincount(mask.ravel(), minlength=19)
#     return frequencies / mask.size

# def compute_spatial_distribution(mask, grid_size=(4, 4)):
#     h, w = mask.shape
#     grid_h, grid_w = h // grid_size[0], w // grid_size[1]
#     spatial_stats = []
#     for i in range(grid_size[0]):
#         for j in range(grid_size[1]):
#             sub_mask = mask[i * grid_h:(i + 1) * grid_h, j * grid_w:(j + 1) * grid_w]
#             frequencies = np.bincount(sub_mask.ravel(), minlength=20)
#             spatial_stats.append(frequencies / sub_mask.size)
#     return np.concatenate(spatial_stats)

# from scipy.ndimage import label as lbl

# def compute_complexity(mask):
#     labeled, num_features = lbl(mask)
#     return num_features

# %% [markdown]
# # Dataset Statistics

# %% [markdown]
# ## Critical/NON Critical percentages

# %%
total = len(labels)
percent_0 = (labels == 0).sum() / total * 100
percent_1 = (labels == 1).sum() / total * 100
percent_other = 100 - (percent_0 + percent_1)

print(f"Percentuale di NON Critici: {percent_0:.2f}%")
print(f"Percentuale di Critici: {percent_1:.2f}%")
print(f"Percentuale di valori ERRORE: {percent_other:.2f}%")
# Out:
# Percentuale di NON Critici: 11.90%
# Percentuale di Critici: 88.10%
# Percentuale di valori ERRORE: 0.00%

# %%
faults = load_faults("./faulty_output_dataset/Fast-SCNN_38_fault_list_30_3.csv")
filtered_faults = filter_faults(faults, bit=30)
print(faults[0])
print(filtered_faults[0])
# Out:
# {'injection': 0, 'layer_name': 'learning_to_downsample.conv.conv.0', 'tensor_index': (26, 1, 2, 0), 'bit': 30}
# {'injection': 0, 'layer_name': 'learning_to_downsample.conv.conv.0', 'tensor_index': (26, 1, 2, 0), 'bit': 30}

# %%
frame_ids = df['Frame']
unique_frame_ids = set(frame_ids)
if len(unique_frame_ids):
    print("All Frames from Cityscapes Validation Partition are present in the FOD (Frame column).")
else:
    print("NOT All Frames from Cityscapes Validation Partition are present in the FOD (Frame column).")
# Out:
# All Frames from Cityscapes Validation Partition are present in the FOD (Frame column).

# %%
fault_ids = df['Injection']
unique_fault_ids = set(fault_ids)
filtered_fault_ids = set(filtered_faults.keys())
all_ids_present = filtered_fault_ids.issubset(unique_fault_ids)
if all_ids_present:
    print("All 30 bit Injections in the dictionary are present in the FOD (Injection column).")
else:
    print("NOT All 30 bit Injections in the dictionary are present in the FOD (Injection column).")
    missing_ids = filtered_fault_ids - unique_fault_ids
    print("Missing Injections:", missing_ids)
# Out:
# All 30 bit Injections in the dictionary are present in the FOD (Injection column).

# %%
# frame_id = 0
# fault_id = 0
# frame, fault, mIoU, pa, cmask, fmask, label = fod_dataset[67990]
# # Calcolo delle feature
# fmask = fmask.cpu().numpy().astype(np.int64)
# freq = compute_class_frequencies(fmask)
# complexity = compute_complexity(fmask)
# feature_vector = np.concatenate([freq, [complexity]])
# print(feature_vector.shape)

# %% [markdown]
# ## Clustering
# Grouping by dominant classes. Basing on how many classes are present in the faulty mask (1° grouping), we group by dominant (highest areas) classes. If more than 3 classes are present, we consider only the top 3.

# %%
import numpy as np
from collections import defaultdict

features = np.load('./faulty_output_dataset/area.npy')
freq = features[:, :19]
clusters = defaultdict(list)

for idx, row in enumerate(freq):
    non_zero_count = np.count_nonzero(row)
    clusters[non_zero_count].append(idx)

def estrai_indici(vettore):
    indici_frequenze = []
    for row in vettore:
        non_zero_indices = np.where(row > 0)[0]
        if len(non_zero_indices) == 1:
            # Se c'è solo una frequenza maggiore di 0, prendi l'indice
            indici_frequenze.append([non_zero_indices[0]])
        elif len(non_zero_indices) == 2:
            # Se ce ne sono due, prendi gli indici delle due frequenze
            indici_frequenze.append(non_zero_indices.tolist())
        elif len(non_zero_indices) == 3:
            # Se ce ne sono tre, prendi gli indici delle tre frequenze
            indici_frequenze.append(non_zero_indices.tolist())
        else:
            # Se ci sono più di tre, prendi i primi tre indici con le frequenze più alte
            sorted_indices = np.argsort(-row[non_zero_indices])[:3]  # Indici delle 3 frequenze maggiori
            indici_frequenze.append(non_zero_indices[sorted_indices].tolist())
    return indici_frequenze

result = estrai_indici(freq)
top_3_tuples = [tuple(row) for row in result] #[tuple(sorted(row)) for row in result]
clusters_freq = defaultdict(list)

for non_zero_count, indices in clusters.items():
    for idx in indices:
        top_classes_subset = tuple(top_3_tuples[idx][:non_zero_count])
        clusters_freq[(non_zero_count, top_classes_subset)].append(idx)

clusters_freq = dict(sorted(clusters_freq.items()))

for k, v in clusters_freq.items():
    print(f"Cluster with {k[0]} non-zero elements of classes {[cityscapes_labels_dict[i]['name'] for i in k[1]]}: {len(v)} masks")
# Out:
# Cluster with 1 non-zero elements of classes ['road']: 29152 masks
# Cluster with 1 non-zero elements of classes ['sidewalk']: 23 masks
# Cluster with 1 non-zero elements of classes ['building']: 12 masks
# Cluster with 1 non-zero elements of classes ['wall']: 12 masks
# Cluster with 1 non-zero elements of classes ['fence']: 9 masks
# Cluster with 1 non-zero elements of classes ['traffic light']: 10 masks
# Cluster with 1 non-zero elements of classes ['traffic sign']: 17 masks
# Cluster with 1 non-zero elements of classes ['vegetation']: 9 masks
# Cluster with 1 non-zero elements of classes ['sky']: 8 masks
# Cluster with 1 non-zero elements of classes ['car']: 2 masks
# Cluster with 1 non-zero elements of classes ['bus']: 8 masks
# Cluster with 1 non-zero elements of classes ['train']: 20 masks
# Cluster with 1 non-zero elements of classes ['motorcycle']: 7 masks
# Cluster with 2 non-zero elements of classes ['road', 'sidewalk']: 204 masks
# Cluster with 2 non-zero elements of classes ['road', 'building']: 47 masks
# Cluster with 2 non-zero elements of classes ['road', 'fence']: 9 masks
# Cluster with 2 non-zero elements of classes ['road', 'pole']: 4 masks
# Cluster with 2 non-zero elements of classes ['road', 'traffic light']: 7 masks
# Cluster with 2 non-zero elements of classes ['road', 'traffic sign']: 22 masks
# Cluster with 2 non-zero elements of classes ['road', 'terrain']: 1 masks
# Cluster with 2 non-zero elements of classes ['road', 'sky']: 45 masks
# Cluster with 2 non-zero elements of classes ['road', 'rider']: 3 masks
# Cluster with 2 non-zero elements of classes ['road', 'car']: 35 masks
# Cluster with 2 non-zero elements of classes ['road', 'truck']: 25 masks
# Cluster with 2 non-zero elements of classes ['road', 'train']: 2 masks
# Cluster with 2 non-zero elements of classes ['sidewalk', 'building']: 14 masks
# Cluster with 2 non-zero elements of classes ['sidewalk', 'wall']: 39 masks
# Cluster with 2 non-zero elements of classes ['sidewalk', 'car']: 6 masks
# Cluster with 2 non-zero elements of classes ['building', 'fence']: 6 masks
# Cluster with 2 non-zero elements of classes ['building', 'pole']: 7 masks
# Cluster with 2 non-zero elements of classes ['building', 'traffic sign']: 1 masks
# Cluster with 2 non-zero elements of classes ['building', 'vegetation']: 13 masks
# Cluster with 2 non-zero elements of classes ['building', 'sky']: 4 masks
# Cluster with 2 non-zero elements of classes ['building', 'person']: 6 masks
# Cluster with 2 non-zero elements of classes ['building', 'truck']: 3 masks
# Cluster with 2 non-zero elements of classes ['building', 'train']: 19 masks
# Cluster with 2 non-zero elements of classes ['fence', 'traffic sign']: 3 masks
# Cluster with 2 non-zero elements of classes ['fence', 'person']: 7 masks
# Cluster with 2 non-zero elements of classes ['fence', 'rider']: 8 masks
# Cluster with 2 non-zero elements of classes ['fence', 'car']: 1 masks
# Cluster with 2 non-zero elements of classes ['fence', 'train']: 3 masks
# Cluster with 2 non-zero elements of classes ['pole', 'traffic sign']: 3 masks
# Cluster with 2 non-zero elements of classes ['pole', 'train']: 2 masks
# Cluster with 2 non-zero elements of classes ['traffic sign', 'bus']: 1 masks
# Cluster with 2 non-zero elements of classes ['traffic sign', 'train']: 1 masks
# Cluster with 2 non-zero elements of classes ['vegetation', 'train']: 3 masks
# Cluster with 2 non-zero elements of classes ['car', 'bus']: 1 masks
# Cluster with 2 non-zero elements of classes ['truck', 'bus']: 1 masks
# Cluster with 2 non-zero elements of classes ['bus', 'train']: 7 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'building']: 107 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'wall']: 18 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'fence']: 2 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'pole']: 61 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'traffic sign']: 8 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'vegetation']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'terrain']: 2 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'sky']: 16 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'car']: 7 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'train']: 23 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'motorcycle']: 2 masks
# Cluster with 3 non-zero elements of classes ['road', 'sidewalk', 'bicycle']: 4 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'fence']: 7 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'pole']: 11 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'traffic light']: 5 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'traffic sign']: 22 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'vegetation']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'sky']: 16 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'car']: 9 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'truck']: 10 masks
# Cluster with 3 non-zero elements of classes ['road', 'building', 'train']: 21 masks
# Cluster with 3 non-zero elements of classes ['road', 'fence', 'pole']: 2 masks
# Cluster with 3 non-zero elements of classes ['road', 'fence', 'traffic sign']: 7 masks
# Cluster with 3 non-zero elements of classes ['road', 'fence', 'person']: 14 masks
# Cluster with 3 non-zero elements of classes ['road', 'fence', 'rider']: 5 masks
# Cluster with 3 non-zero elements of classes ['road', 'fence', 'car']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'fence', 'train']: 2 masks
# Cluster with 3 non-zero elements of classes ['road', 'pole', 'traffic light']: 8 masks
# Cluster with 3 non-zero elements of classes ['road', 'pole', 'traffic sign']: 6 masks
# Cluster with 3 non-zero elements of classes ['road', 'pole', 'sky']: 13 masks
# Cluster with 3 non-zero elements of classes ['road', 'pole', 'rider']: 4 masks
# Cluster with 3 non-zero elements of classes ['road', 'pole', 'car']: 4 masks
# Cluster with 3 non-zero elements of classes ['road', 'pole', 'train']: 11 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic light', 'traffic sign']: 2 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic light', 'vegetation']: 3 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic light', 'sky']: 22 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic light', 'truck']: 7 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic light', 'bus']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic sign', 'sky']: 15 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic sign', 'car']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic sign', 'truck']: 11 masks
# Cluster with 3 non-zero elements of classes ['road', 'traffic sign', 'train']: 6 masks
# Cluster with 3 non-zero elements of classes ['road', 'vegetation', 'sky']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'vegetation', 'train']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'sky', 'rider']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'sky', 'car']: 20 masks
# Cluster with 3 non-zero elements of classes ['road', 'sky', 'train']: 4 masks
# Cluster with 3 non-zero elements of classes ['road', 'person', 'car']: 7 masks
# Cluster with 3 non-zero elements of classes ['road', 'rider', 'car']: 2 masks
# Cluster with 3 non-zero elements of classes ['road', 'rider', 'truck']: 1 masks
# Cluster with 3 non-zero elements of classes ['road', 'car', 'truck']: 15 masks
# Cluster with 3 non-zero elements of classes ['road', 'car', 'train']: 5 masks
# Cluster with 3 non-zero elements of classes ['road', 'truck', 'bus']: 14 masks
# Cluster with 3 non-zero elements of classes ['road', 'bus', 'train']: 4 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'building', 'wall']: 21 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'building', 'fence']: 2 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'building', 'pole']: 11 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'building', 'sky']: 1 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'building', 'car']: 10 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'building', 'truck']: 5 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'wall', 'fence']: 14 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'wall', 'pole']: 2 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'wall', 'vegetation']: 3 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'wall', 'terrain']: 5 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'wall', 'car']: 2 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'wall', 'train']: 2 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'wall', 'bicycle']: 1 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'fence', 'pole']: 9 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'pole', 'train']: 10 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'vegetation', 'terrain']: 11 masks
# Cluster with 3 non-zero elements of classes ['sidewalk', 'bus', 'train']: 4 masks
# Cluster with 3 non-zero elements of classes ['building', 'fence', 'traffic sign']: 1 masks
# Cluster with 3 non-zero elements of classes ['building', 'fence', 'vegetation']: 1 masks
# Cluster with 3 non-zero elements of classes ['building', 'fence', 'rider']: 1 masks
# Cluster with 3 non-zero elements of classes ['building', 'fence', 'train']: 2 masks
# Cluster with 3 non-zero elements of classes ['building', 'pole', 'traffic sign']: 8 masks
# Cluster with 3 non-zero elements of classes ['building', 'pole', 'vegetation']: 15 masks
# Cluster with 3 non-zero elements of classes ['building', 'pole', 'rider']: 1 masks
# Cluster with 3 non-zero elements of classes ['building', 'pole', 'train']: 20 masks
# Cluster with 3 non-zero elements of classes ['building', 'traffic light', 'vegetation']: 1 masks
# Cluster with 3 non-zero elements of classes ['building', 'traffic sign', 'vegetation']: 8 masks
# Cluster with 3 non-zero elements of classes ['building', 'traffic sign', 'sky']: 4 masks
# Cluster with 3 non-zero elements of classes ['building', 'traffic sign', 'train']: 1 masks
# Cluster with 3 non-zero elements of classes ['building', 'vegetation', 'sky']: 2 masks
# Cluster with 3 non-zero elements of classes ['building', 'vegetation', 'train']: 40 masks
# Cluster with 3 non-zero elements of classes ['building', 'sky', 'train']: 1 masks
# Cluster with 3 non-zero elements of classes ['building', 'bus', 'train']: 9 masks
# Cluster with 3 non-zero elements of classes ['fence', 'pole', 'train']: 13 masks
# Cluster with 3 non-zero elements of classes ['fence', 'traffic sign', 'person']: 6 masks
# Cluster with 3 non-zero elements of classes ['fence', 'traffic sign', 'train']: 2 masks
# Cluster with 3 non-zero elements of classes ['fence', 'traffic sign', 'bicycle']: 1 masks
# Cluster with 3 non-zero elements of classes ['fence', 'vegetation', 'person']: 1 masks
# Cluster with 3 non-zero elements of classes ['fence', 'vegetation', 'rider']: 5 masks
# Cluster with 3 non-zero elements of classes ['fence', 'vegetation', 'train']: 1 masks
# Cluster with 3 non-zero elements of classes ['fence', 'terrain', 'bus']: 3 masks
# Cluster with 3 non-zero elements of classes ['fence', 'person', 'rider']: 4 masks
# Cluster with 3 non-zero elements of classes ['fence', 'person', 'bus']: 3 masks
# Cluster with 3 non-zero elements of classes ['fence', 'person', 'bicycle']: 3 masks
# Cluster with 3 non-zero elements of classes ['fence', 'rider', 'bicycle']: 15 masks
# Cluster with 3 non-zero elements of classes ['fence', 'bus', 'train']: 2 masks
# Cluster with 3 non-zero elements of classes ['fence', 'train', 'bicycle']: 1 masks
# Cluster with 3 non-zero elements of classes ['pole', 'traffic sign', 'bus']: 1 masks
# Cluster with 3 non-zero elements of classes ['pole', 'traffic sign', 'train']: 10 masks
# Cluster with 3 non-zero elements of classes ['pole', 'person', 'car']: 7 masks
# Cluster with 3 non-zero elements of classes ['pole', 'truck', 'bus']: 1 masks
# Cluster with 3 non-zero elements of classes ['pole', 'bus', 'train']: 4 masks
# Cluster with 3 non-zero elements of classes ['traffic light', 'vegetation', 'bus']: 13 masks
# Cluster with 3 non-zero elements of classes ['traffic sign', 'truck', 'bus']: 9 masks
# Cluster with 3 non-zero elements of classes ['traffic sign', 'bus', 'train']: 14 masks
# Cluster with 3 non-zero elements of classes ['vegetation', 'terrain', 'bus']: 1 masks
# Cluster with 3 non-zero elements of classes ['vegetation', 'car', 'bus']: 2 masks
# Cluster with 3 non-zero elements of classes ['vegetation', 'truck', 'bus']: 1 masks
# Cluster with 3 non-zero elements of classes ['vegetation', 'bus', 'train']: 10 masks
# Cluster with 3 non-zero elements of classes ['car', 'truck', 'bus']: 9 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'building']: 43 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'wall']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'pole']: 13 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'traffic light']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'traffic sign']: 11 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'vegetation']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'terrain']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'sky']: 10 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'car']: 9 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'train']: 24 masks
# Cluster with 4 non-zero elements of classes ['road', 'sidewalk', 'motorcycle']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'sidewalk']: 38 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'pole']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'traffic light']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'traffic sign']: 6 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'sky']: 20 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'car']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'truck']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'building', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'wall', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'fence', 'sidewalk']: 10 masks
# Cluster with 4 non-zero elements of classes ['road', 'fence', 'building']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'fence', 'pole']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'fence', 'rider']: 6 masks
# Cluster with 4 non-zero elements of classes ['road', 'fence', 'bicycle']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'sidewalk']: 21 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'building']: 13 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'traffic light']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'traffic sign']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'sky']: 7 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'rider']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'car']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'pole', 'train']: 5 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic light', 'sidewalk']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic light', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic light', 'vegetation']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic light', 'sky']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic light', 'car']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic light', 'truck']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic sign', 'sidewalk']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic sign', 'building']: 10 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic sign', 'pole']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic sign', 'sky']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic sign', 'car']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic sign', 'truck']: 16 masks
# Cluster with 4 non-zero elements of classes ['road', 'traffic sign', 'train']: 13 masks
# Cluster with 4 non-zero elements of classes ['road', 'sky', 'sidewalk']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'sky', 'building']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'sky', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'sky', 'pole']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'sky', 'rider']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'sky', 'bus']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'sky', 'train']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'rider', 'fence']: 5 masks
# Cluster with 4 non-zero elements of classes ['road', 'car', 'sidewalk']: 16 masks
# Cluster with 4 non-zero elements of classes ['road', 'car', 'building']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'car', 'pole']: 18 masks
# Cluster with 4 non-zero elements of classes ['road', 'car', 'sky']: 13 masks
# Cluster with 4 non-zero elements of classes ['road', 'car', 'truck']: 21 masks
# Cluster with 4 non-zero elements of classes ['road', 'car', 'bus']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'car', 'train']: 7 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'sidewalk']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'building']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'traffic light']: 4 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'traffic sign']: 5 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'rider']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'truck', 'car']: 7 masks
# Cluster with 4 non-zero elements of classes ['road', 'bus', 'truck']: 3 masks
# Cluster with 4 non-zero elements of classes ['road', 'bus', 'train']: 15 masks
# Cluster with 4 non-zero elements of classes ['road', 'train', 'sidewalk']: 11 masks
# Cluster with 4 non-zero elements of classes ['road', 'train', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'train', 'wall']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'train', 'pole']: 24 masks
# Cluster with 4 non-zero elements of classes ['road', 'train', 'sky']: 5 masks
# Cluster with 4 non-zero elements of classes ['road', 'train', 'car']: 2 masks
# Cluster with 4 non-zero elements of classes ['road', 'train', 'bus']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'motorcycle', 'sidewalk']: 1 masks
# Cluster with 4 non-zero elements of classes ['road', 'bicycle', 'rider']: 6 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'building']: 28 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'wall']: 9 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'fence']: 5 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'pole']: 3 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'traffic sign']: 2 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'vegetation']: 2 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'terrain']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'train']: 3 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'road', 'bicycle']: 4 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'building', 'road']: 6 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'building', 'fence']: 7 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'building', 'pole']: 3 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'building', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'wall', 'building']: 4 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'wall', 'fence']: 4 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'wall', 'pole']: 2 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'wall', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'wall', 'terrain']: 2 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'wall', 'rider']: 2 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'wall', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'fence', 'road']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'fence', 'wall']: 9 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'pole', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'pole', 'building']: 4 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'pole', 'wall']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'pole', 'fence']: 6 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'vegetation', 'road']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'terrain', 'vegetation']: 6 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'person', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'car', 'road']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'car', 'wall']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'car', 'bus']: 2 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'car', 'train']: 2 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'bus', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'train', 'road']: 5 masks
# Cluster with 4 non-zero elements of classes ['sidewalk', 'train', 'building']: 3 masks
# Cluster with 4 non-zero elements of classes ['building', 'road', 'sidewalk']: 12 masks
# Cluster with 4 non-zero elements of classes ['building', 'road', 'fence']: 4 masks
# Cluster with 4 non-zero elements of classes ['building', 'road', 'pole']: 8 masks
# Cluster with 4 non-zero elements of classes ['building', 'road', 'traffic sign']: 4 masks
# Cluster with 4 non-zero elements of classes ['building', 'road', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'road', 'person']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'road', 'truck']: 4 masks
# Cluster with 4 non-zero elements of classes ['building', 'sidewalk', 'road']: 6 masks
# Cluster with 4 non-zero elements of classes ['building', 'sidewalk', 'pole']: 2 masks
# Cluster with 4 non-zero elements of classes ['building', 'sidewalk', 'sky']: 2 masks
# Cluster with 4 non-zero elements of classes ['building', 'sidewalk', 'truck']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'fence', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'pole', 'road']: 7 masks
# Cluster with 4 non-zero elements of classes ['building', 'pole', 'traffic sign']: 4 masks
# Cluster with 4 non-zero elements of classes ['building', 'pole', 'vegetation']: 4 masks
# Cluster with 4 non-zero elements of classes ['building', 'pole', 'rider']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'pole', 'car']: 3 masks
# Cluster with 4 non-zero elements of classes ['building', 'pole', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'traffic sign', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['building', 'traffic sign', 'pole']: 26 masks
# Cluster with 4 non-zero elements of classes ['building', 'traffic sign', 'traffic light']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'traffic sign', 'vegetation']: 5 masks
# Cluster with 4 non-zero elements of classes ['building', 'traffic sign', 'sky']: 2 masks
# Cluster with 4 non-zero elements of classes ['building', 'traffic sign', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'vegetation', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'vegetation', 'traffic light']: 2 masks
# Cluster with 4 non-zero elements of classes ['building', 'vegetation', 'traffic sign']: 4 masks
# Cluster with 4 non-zero elements of classes ['building', 'vegetation', 'sky']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'vegetation', 'car']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'sky', 'bus']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'person', 'pole']: 2 masks
# Cluster with 4 non-zero elements of classes ['building', 'person', 'traffic light']: 2 masks
# Cluster with 4 non-zero elements of classes ['building', 'truck', 'sidewalk']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'truck', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'train', 'road']: 2 masks
# Cluster with 4 non-zero elements of classes ['building', 'train', 'pole']: 14 masks
# Cluster with 4 non-zero elements of classes ['building', 'train', 'traffic sign']: 1 masks
# Cluster with 4 non-zero elements of classes ['building', 'train', 'vegetation']: 2 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'sidewalk']: 2 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'wall']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'traffic sign']: 17 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'person']: 5 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'rider']: 4 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'car']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'bus']: 4 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'train']: 2 masks
# Cluster with 4 non-zero elements of classes ['fence', 'road', 'bicycle']: 4 masks
# Cluster with 4 non-zero elements of classes ['fence', 'sidewalk', 'wall']: 3 masks
# Cluster with 4 non-zero elements of classes ['fence', 'sidewalk', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'sidewalk', 'person']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'building', 'pole']: 7 masks
# Cluster with 4 non-zero elements of classes ['fence', 'building', 'traffic sign']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'building', 'rider']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'traffic sign', 'road']: 13 masks
# Cluster with 4 non-zero elements of classes ['fence', 'traffic sign', 'building']: 2 masks
# Cluster with 4 non-zero elements of classes ['fence', 'traffic sign', 'pole']: 3 masks
# Cluster with 4 non-zero elements of classes ['fence', 'traffic sign', 'person']: 4 masks
# Cluster with 4 non-zero elements of classes ['fence', 'traffic sign', 'rider']: 7 masks
# Cluster with 4 non-zero elements of classes ['fence', 'traffic sign', 'bus']: 10 masks
# Cluster with 4 non-zero elements of classes ['fence', 'traffic sign', 'train']: 4 masks
# Cluster with 4 non-zero elements of classes ['fence', 'person', 'wall']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'person', 'traffic sign']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'rider', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'rider', 'person']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'rider', 'bicycle']: 3 masks
# Cluster with 4 non-zero elements of classes ['fence', 'car', 'road']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'car', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bus', 'road']: 2 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bus', 'traffic sign']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bus', 'vegetation']: 3 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bus', 'person']: 13 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bus', 'rider']: 2 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bus', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'train', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['fence', 'train', 'pole']: 2 masks
# Cluster with 4 non-zero elements of classes ['fence', 'train', 'traffic sign']: 10 masks
# Cluster with 4 non-zero elements of classes ['fence', 'train', 'bus']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bicycle', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bicycle', 'building']: 11 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bicycle', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['fence', 'bicycle', 'rider']: 14 masks
# Cluster with 4 non-zero elements of classes ['pole', 'road', 'sidewalk']: 4 masks
# Cluster with 4 non-zero elements of classes ['pole', 'road', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['pole', 'road', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['pole', 'sidewalk', 'road']: 1 masks
# Cluster with 4 non-zero elements of classes ['pole', 'sidewalk', 'fence']: 7 masks
# Cluster with 4 non-zero elements of classes ['pole', 'traffic sign', 'traffic light']: 2 masks
# Cluster with 4 non-zero elements of classes ['traffic light', 'traffic sign', 'bus']: 10 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'road', 'building']: 2 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'road', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'road', 'traffic light']: 3 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'road', 'truck']: 9 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'road', 'bus']: 4 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'road', 'train']: 2 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'building', 'road']: 2 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'building', 'traffic light']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'fence', 'bus']: 3 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'fence', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'pole', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'pole', 'building']: 2 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'pole', 'traffic light']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'pole', 'vegetation']: 5 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'pole', 'truck']: 2 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'truck', 'road']: 3 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'truck', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'bus', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'bus', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'train', 'road']: 3 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'train', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'train', 'truck']: 3 masks
# Cluster with 4 non-zero elements of classes ['traffic sign', 'train', 'bus']: 7 masks
# Cluster with 4 non-zero elements of classes ['vegetation', 'road', 'sky']: 1 masks
# Cluster with 4 non-zero elements of classes ['vegetation', 'building', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['vegetation', 'building', 'car']: 11 masks
# Cluster with 4 non-zero elements of classes ['vegetation', 'traffic sign', 'building']: 3 masks
# Cluster with 4 non-zero elements of classes ['vegetation', 'traffic sign', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['terrain', 'road', 'building']: 2 masks
# Cluster with 4 non-zero elements of classes ['terrain', 'vegetation', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['car', 'road', 'truck']: 3 masks
# Cluster with 4 non-zero elements of classes ['car', 'road', 'bus']: 4 masks
# Cluster with 4 non-zero elements of classes ['car', 'building', 'pole']: 3 masks
# Cluster with 4 non-zero elements of classes ['car', 'pole', 'building']: 4 masks
# Cluster with 4 non-zero elements of classes ['car', 'pole', 'sky']: 1 masks
# Cluster with 4 non-zero elements of classes ['car', 'vegetation', 'fence']: 4 masks
# Cluster with 4 non-zero elements of classes ['car', 'vegetation', 'traffic sign']: 1 masks
# Cluster with 4 non-zero elements of classes ['car', 'person', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['truck', 'building', 'traffic sign']: 1 masks
# Cluster with 4 non-zero elements of classes ['truck', 'building', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['truck', 'car', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['truck', 'car', 'bus']: 1 masks
# Cluster with 4 non-zero elements of classes ['truck', 'bus', 'vegetation']: 2 masks
# Cluster with 4 non-zero elements of classes ['truck', 'bus', 'car']: 2 masks
# Cluster with 4 non-zero elements of classes ['bus', 'road', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['bus', 'traffic sign', 'car']: 1 masks
# Cluster with 4 non-zero elements of classes ['bus', 'traffic sign', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['bus', 'vegetation', 'car']: 1 masks
# Cluster with 4 non-zero elements of classes ['bus', 'car', 'vegetation']: 3 masks
# Cluster with 4 non-zero elements of classes ['bus', 'truck', 'person']: 2 masks
# Cluster with 4 non-zero elements of classes ['bus', 'truck', 'train']: 1 masks
# Cluster with 4 non-zero elements of classes ['bus', 'train', 'road']: 1 masks
# Cluster with 4 non-zero elements of classes ['bus', 'train', 'traffic sign']: 6 masks
# Cluster with 4 non-zero elements of classes ['bus', 'train', 'vegetation']: 1 masks
# Cluster with 4 non-zero elements of classes ['bus', 'train', 'truck']: 2 masks
# Cluster with 4 non-zero elements of classes ['train', 'road', 'sidewalk']: 15 masks
# Cluster with 4 non-zero elements of classes ['train', 'road', 'building']: 14 masks
# Cluster with 4 non-zero elements of classes ['train', 'road', 'fence']: 2 masks
# Cluster with 4 non-zero elements of classes ['train', 'road', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'road', 'traffic sign']: 3 masks
# Cluster with 4 non-zero elements of classes ['train', 'road', 'sky']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'road', 'bus']: 2 masks
# Cluster with 4 non-zero elements of classes ['train', 'sidewalk', 'road']: 11 masks
# Cluster with 4 non-zero elements of classes ['train', 'sidewalk', 'building']: 18 masks
# Cluster with 4 non-zero elements of classes ['train', 'sidewalk', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'building', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['train', 'building', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'building', 'pole']: 26 masks
# Cluster with 4 non-zero elements of classes ['train', 'building', 'vegetation']: 2 masks
# Cluster with 4 non-zero elements of classes ['train', 'building', 'sky']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'building', 'bus']: 4 masks
# Cluster with 4 non-zero elements of classes ['train', 'fence', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['train', 'fence', 'building']: 3 masks
# Cluster with 4 non-zero elements of classes ['train', 'fence', 'pole']: 2 masks
# Cluster with 4 non-zero elements of classes ['train', 'fence', 'traffic sign']: 4 masks
# Cluster with 4 non-zero elements of classes ['train', 'fence', 'bus']: 3 masks
# Cluster with 4 non-zero elements of classes ['train', 'pole', 'traffic sign']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'pole', 'bus']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'traffic sign', 'road']: 6 masks
# Cluster with 4 non-zero elements of classes ['train', 'traffic sign', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'traffic sign', 'pole']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'traffic sign', 'bus']: 11 masks
# Cluster with 4 non-zero elements of classes ['train', 'vegetation', 'building']: 15 masks
# Cluster with 4 non-zero elements of classes ['train', 'vegetation', 'fence']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'car', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'truck', 'bus']: 7 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'road']: 4 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'sidewalk']: 1 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'building']: 12 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'fence']: 3 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'pole']: 5 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'traffic sign']: 3 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'vegetation']: 5 masks
# Cluster with 4 non-zero elements of classes ['train', 'bus', 'truck']: 1 masks
# Cluster with 4 non-zero elements of classes ['bicycle', 'fence', 'road']: 1 masks
# Cluster with 4 non-zero elements of classes ['bicycle', 'fence', 'building']: 1 masks
# Cluster with 4 non-zero elements of classes ['bicycle', 'fence', 'person']: 3 masks
# Cluster with 4 non-zero elements of classes ['bicycle', 'fence', 'rider']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'building']: 24 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'wall']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'fence']: 5 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'pole']: 21 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'traffic sign']: 18 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'terrain']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'person']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'car']: 4 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'truck']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'bus']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'train']: 31 masks
# Cluster with 5 non-zero elements of classes ['road', 'sidewalk', 'bicycle']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'sidewalk']: 25 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'fence']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'pole']: 14 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'traffic light']: 3 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'traffic sign']: 7 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'sky']: 6 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'truck']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'building', 'train']: 10 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'sidewalk']: 9 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'building']: 4 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'pole']: 9 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'traffic sign']: 3 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'rider']: 8 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'truck']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'train']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'fence', 'bicycle']: 9 masks
# Cluster with 5 non-zero elements of classes ['road', 'pole', 'sidewalk']: 18 masks
# Cluster with 5 non-zero elements of classes ['road', 'pole', 'building']: 9 masks
# Cluster with 5 non-zero elements of classes ['road', 'pole', 'traffic sign']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'pole', 'sky']: 5 masks
# Cluster with 5 non-zero elements of classes ['road', 'pole', 'rider']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'pole', 'car']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'pole', 'train']: 13 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic light', 'sidewalk']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic light', 'building']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic light', 'pole']: 3 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic light', 'vegetation']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic light', 'sky']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'sidewalk']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'building']: 14 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'fence']: 4 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'pole']: 22 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'traffic light']: 8 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'sky']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'car']: 8 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'truck']: 13 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'train']: 24 masks
# Cluster with 5 non-zero elements of classes ['road', 'traffic sign', 'bicycle']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'vegetation', 'sky']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sky', 'building']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'sky', 'pole']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'sky', 'traffic light']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sky', 'vegetation']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sky', 'car']: 4 masks
# Cluster with 5 non-zero elements of classes ['road', 'sky', 'bus']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'sky', 'train']: 4 masks
# Cluster with 5 non-zero elements of classes ['road', 'rider', 'fence']: 3 masks
# Cluster with 5 non-zero elements of classes ['road', 'rider', 'pole']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'rider', 'traffic sign']: 9 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'sidewalk']: 8 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'building']: 3 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'fence']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'pole']: 16 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'traffic sign']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'sky']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'truck']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'car', 'train']: 11 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'building']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'fence']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'pole']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'traffic light']: 3 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'traffic sign']: 11 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'car']: 7 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'bus']: 7 masks
# Cluster with 5 non-zero elements of classes ['road', 'truck', 'train']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'bus', 'sidewalk']: 5 masks
# Cluster with 5 non-zero elements of classes ['road', 'bus', 'sky']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'bus', 'truck']: 3 masks
# Cluster with 5 non-zero elements of classes ['road', 'bus', 'train']: 7 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'sidewalk']: 13 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'building']: 17 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'pole']: 23 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'traffic sign']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'sky']: 9 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'car']: 4 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'truck']: 12 masks
# Cluster with 5 non-zero elements of classes ['road', 'train', 'bus']: 11 masks
# Cluster with 5 non-zero elements of classes ['road', 'motorcycle', 'sidewalk']: 1 masks
# Cluster with 5 non-zero elements of classes ['road', 'bicycle', 'traffic sign']: 2 masks
# Cluster with 5 non-zero elements of classes ['road', 'bicycle', 'rider']: 1 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'building']: 10 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'wall']: 10 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'fence']: 3 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'pole']: 3 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'vegetation']: 1 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'car']: 6 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'train']: 5 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'road', 'bicycle']: 11 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'building', 'road']: 12 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'building', 'wall']: 2 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'building', 'fence']: 7 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'building', 'pole']: 4 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'building', 'train']: 3 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'wall', 'road']: 1 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'wall', 'building']: 3 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'wall', 'fence']: 4 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'wall', 'pole']: 8 masks
# Cluster with 5 non-zero elements of classes ['sidewalk', 'wall', 'train']: 1 masks
# ...
# Cluster with 17 non-zero elements of classes ['wall', 'fence', 'pole']: 2 masks
# Cluster with 17 non-zero elements of classes ['wall', 'rider', 'bus']: 1 masks
# Cluster with 17 non-zero elements of classes ['wall', 'bus', 'vegetation']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'road', 'sidewalk']: 5 masks
# Cluster with 17 non-zero elements of classes ['fence', 'road', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'road', 'traffic sign']: 7 masks
# Cluster with 17 non-zero elements of classes ['fence', 'road', 'terrain']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'road', 'bus']: 2 masks
# Cluster with 17 non-zero elements of classes ['fence', 'road', 'train']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'road', 'bicycle']: 4 masks
# Cluster with 17 non-zero elements of classes ['fence', 'sidewalk', 'road']: 3 masks
# Cluster with 17 non-zero elements of classes ['fence', 'sidewalk', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'sidewalk', 'pole']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'sidewalk', 'traffic sign']: 4 masks
# Cluster with 17 non-zero elements of classes ['fence', 'sidewalk', 'car']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'sidewalk', 'bicycle']: 7 masks
# Cluster with 17 non-zero elements of classes ['fence', 'building', 'sidewalk']: 3 masks
# Cluster with 17 non-zero elements of classes ['fence', 'building', 'wall']: 2 masks
# Cluster with 17 non-zero elements of classes ['fence', 'building', 'pole']: 2 masks
# Cluster with 17 non-zero elements of classes ['fence', 'building', 'train']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'building', 'bicycle']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'pole', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'traffic sign', 'road']: 2 masks
# Cluster with 17 non-zero elements of classes ['fence', 'traffic sign', 'sidewalk']: 4 masks
# Cluster with 17 non-zero elements of classes ['fence', 'traffic sign', 'rider']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'traffic sign', 'bus']: 3 masks
# Cluster with 17 non-zero elements of classes ['fence', 'vegetation', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'rider', 'wall']: 4 masks
# Cluster with 17 non-zero elements of classes ['fence', 'bus', 'sidewalk']: 2 masks
# Cluster with 17 non-zero elements of classes ['fence', 'bus', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['fence', 'bus', 'traffic sign']: 3 masks
# Cluster with 17 non-zero elements of classes ['fence', 'bicycle', 'sidewalk']: 1 masks
# Cluster with 17 non-zero elements of classes ['pole', 'road', 'building']: 2 masks
# Cluster with 17 non-zero elements of classes ['pole', 'sidewalk', 'fence']: 1 masks
# Cluster with 17 non-zero elements of classes ['pole', 'building', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['pole', 'building', 'fence']: 1 masks
# Cluster with 17 non-zero elements of classes ['pole', 'wall', 'sidewalk']: 1 masks
# Cluster with 17 non-zero elements of classes ['pole', 'train', 'sidewalk']: 1 masks
# Cluster with 17 non-zero elements of classes ['pole', 'train', 'building']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic light', 'road', 'building']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic light', 'building', 'road']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic light', 'pole', 'road']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic light', 'pole', 'fence']: 4 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'road', 'fence']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'road', 'traffic light']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'road', 'bus']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'sidewalk', 'train']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'building', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'building', 'fence']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'building', 'vegetation']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'building', 'train']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'fence', 'sidewalk']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'fence', 'wall']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'fence', 'pole']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'fence', 'car']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'fence', 'bus']: 2 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'pole', 'fence']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'rider', 'pole']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'bus', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'bus', 'fence']: 1 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'train', 'fence']: 3 masks
# Cluster with 17 non-zero elements of classes ['traffic sign', 'train', 'bus']: 1 masks
# Cluster with 17 non-zero elements of classes ['vegetation', 'road', 'sidewalk']: 23 masks
# Cluster with 17 non-zero elements of classes ['vegetation', 'road', 'building']: 3 masks
# Cluster with 17 non-zero elements of classes ['vegetation', 'road', 'sky']: 1 masks
# Cluster with 17 non-zero elements of classes ['vegetation', 'sidewalk', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['terrain', 'pole', 'fence']: 2 masks
# Cluster with 17 non-zero elements of classes ['sky', 'road', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['sky', 'road', 'vegetation']: 1 masks
# Cluster with 17 non-zero elements of classes ['rider', 'building', 'vegetation']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'road', 'pole']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'road', 'traffic sign']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'building', 'pole']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'pole', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'traffic sign', 'pole']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'vegetation', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'vegetation', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'vegetation', 'truck']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'truck', 'traffic sign']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'bicycle', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['car', 'bicycle', 'motorcycle']: 4 masks
# Cluster with 17 non-zero elements of classes ['truck', 'road', 'traffic light']: 1 masks
# Cluster with 17 non-zero elements of classes ['truck', 'bus', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['bus', 'sidewalk', 'pole']: 1 masks
# Cluster with 17 non-zero elements of classes ['bus', 'fence', 'traffic sign']: 2 masks
# Cluster with 17 non-zero elements of classes ['bus', 'traffic sign', 'train']: 1 masks
# Cluster with 17 non-zero elements of classes ['bus', 'vegetation', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['bus', 'vegetation', 'sky']: 1 masks
# Cluster with 17 non-zero elements of classes ['bus', 'car', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['bus', 'train', 'building']: 1 masks
# Cluster with 17 non-zero elements of classes ['train', 'building', 'vegetation']: 1 masks
# Cluster with 17 non-zero elements of classes ['train', 'pole', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['train', 'traffic sign', 'fence']: 1 masks
# Cluster with 17 non-zero elements of classes ['train', 'vegetation', 'sky']: 1 masks
# Cluster with 17 non-zero elements of classes ['bicycle', 'road', 'fence']: 1 masks
# Cluster with 17 non-zero elements of classes ['bicycle', 'road', 'pole']: 3 masks
# Cluster with 17 non-zero elements of classes ['bicycle', 'road', 'rider']: 8 masks
# Cluster with 17 non-zero elements of classes ['bicycle', 'sidewalk', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['bicycle', 'pole', 'rider']: 1 masks
# Cluster with 17 non-zero elements of classes ['bicycle', 'vegetation', 'road']: 1 masks
# Cluster with 17 non-zero elements of classes ['bicycle', 'car', 'motorcycle']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'building', 'sidewalk']: 19 masks
# Cluster with 18 non-zero elements of classes ['road', 'building', 'traffic light']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'building', 'traffic sign']: 2 masks
# Cluster with 18 non-zero elements of classes ['road', 'building', 'vegetation']: 93 masks
# Cluster with 18 non-zero elements of classes ['road', 'building', 'sky']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'building', 'person']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'building', 'car']: 43 masks
# Cluster with 18 non-zero elements of classes ['road', 'fence', 'sidewalk']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'fence', 'wall']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'fence', 'traffic sign']: 3 masks
# Cluster with 18 non-zero elements of classes ['road', 'fence', 'bus']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'pole', 'traffic sign']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'traffic light', 'building']: 2 masks
# Cluster with 18 non-zero elements of classes ['road', 'traffic sign', 'pole']: 3 masks
# Cluster with 18 non-zero elements of classes ['road', 'vegetation', 'sidewalk']: 2 masks
# Cluster with 18 non-zero elements of classes ['road', 'vegetation', 'building']: 49 masks
# Cluster with 18 non-zero elements of classes ['road', 'vegetation', 'pole']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'vegetation', 'traffic light']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'vegetation', 'sky']: 16 masks
# Cluster with 18 non-zero elements of classes ['road', 'vegetation', 'person']: 14 masks
# Cluster with 18 non-zero elements of classes ['road', 'vegetation', 'car']: 4 masks
# Cluster with 18 non-zero elements of classes ['road', 'sky', 'car']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'rider', 'fence']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'car', 'vegetation']: 1 masks
# Cluster with 18 non-zero elements of classes ['road', 'bus', 'wall']: 4 masks
# Cluster with 18 non-zero elements of classes ['sidewalk', 'wall', 'fence']: 1 masks
# Cluster with 18 non-zero elements of classes ['sidewalk', 'car', 'pole']: 3 masks
# Cluster with 18 non-zero elements of classes ['building', 'road', 'sidewalk']: 2 masks
# Cluster with 18 non-zero elements of classes ['building', 'road', 'traffic sign']: 1 masks
# Cluster with 18 non-zero elements of classes ['building', 'road', 'vegetation']: 1 masks
# Cluster with 18 non-zero elements of classes ['building', 'sidewalk', 'road']: 2 masks
# Cluster with 18 non-zero elements of classes ['building', 'sidewalk', 'fence']: 4 masks
# Cluster with 18 non-zero elements of classes ['building', 'sidewalk', 'bus']: 1 masks
# Cluster with 18 non-zero elements of classes ['building', 'pole', 'road']: 1 masks
# Cluster with 18 non-zero elements of classes ['building', 'pole', 'fence']: 1 masks
# Cluster with 18 non-zero elements of classes ['building', 'traffic sign', 'pole']: 2 masks
# Cluster with 18 non-zero elements of classes ['fence', 'road', 'sidewalk']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'road', 'traffic sign']: 3 masks
# Cluster with 18 non-zero elements of classes ['fence', 'road', 'bus']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'road', 'bicycle']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'sidewalk', 'road']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'building', 'wall']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'building', 'bicycle']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'pole', 'rider']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'traffic sign', 'sidewalk']: 1 masks
# Cluster with 18 non-zero elements of classes ['fence', 'bicycle', 'sidewalk']: 2 masks
# Cluster with 18 non-zero elements of classes ['fence', 'bicycle', 'pole']: 1 masks
# Cluster with 18 non-zero elements of classes ['pole', 'building', 'road']: 1 masks
# Cluster with 18 non-zero elements of classes ['pole', 'train', 'road']: 1 masks
# Cluster with 18 non-zero elements of classes ['pole', 'train', 'sidewalk']: 1 masks
# Cluster with 18 non-zero elements of classes ['traffic light', 'building', 'vegetation']: 1 masks
# Cluster with 18 non-zero elements of classes ['traffic light', 'pole', 'fence']: 1 masks
# Cluster with 18 non-zero elements of classes ['traffic light', 'pole', 'vegetation']: 1 masks
# Cluster with 18 non-zero elements of classes ['traffic sign', 'road', 'fence']: 1 masks
# Cluster with 18 non-zero elements of classes ['traffic sign', 'pole', 'road']: 1 masks
# Cluster with 18 non-zero elements of classes ['vegetation', 'road', 'sidewalk']: 4 masks
# Cluster with 18 non-zero elements of classes ['vegetation', 'road', 'building']: 13 masks
# Cluster with 18 non-zero elements of classes ['rider', 'road', 'building']: 2 masks
# Cluster with 18 non-zero elements of classes ['car', 'vegetation', 'road']: 1 masks
# Cluster with 18 non-zero elements of classes ['train', 'road', 'vegetation']: 1 masks
# Cluster with 18 non-zero elements of classes ['bicycle', 'road', 'pole']: 1 masks
# Cluster with 18 non-zero elements of classes ['bicycle', 'road', 'vegetation']: 2 masks
# Cluster with 18 non-zero elements of classes ['bicycle', 'pole', 'road']: 1 masks
# Cluster with 18 non-zero elements of classes ['bicycle', 'car', 'motorcycle']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'building', 'sidewalk']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'building', 'wall']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'building', 'vegetation']: 10 masks
# Cluster with 19 non-zero elements of classes ['road', 'building', 'car']: 21 masks
# Cluster with 19 non-zero elements of classes ['road', 'fence', 'traffic sign']: 3 masks
# Cluster with 19 non-zero elements of classes ['road', 'fence', 'bus']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'traffic sign', 'building']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'traffic sign', 'rider']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'vegetation', 'sidewalk']: 16 masks
# Cluster with 19 non-zero elements of classes ['road', 'vegetation', 'building']: 7 masks
# Cluster with 19 non-zero elements of classes ['road', 'vegetation', 'pole']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'vegetation', 'person']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'vegetation', 'car']: 1 masks
# Cluster with 19 non-zero elements of classes ['road', 'truck', 'building']: 1 masks
# Cluster with 19 non-zero elements of classes ['building', 'road', 'sidewalk']: 1 masks
# Cluster with 19 non-zero elements of classes ['fence', 'road', 'traffic sign']: 1 masks
# Cluster with 19 non-zero elements of classes ['traffic sign', 'truck', 'road']: 1 masks
# Cluster with 19 non-zero elements of classes ['vegetation', 'road', 'sidewalk']: 1 masks
# Cluster with 19 non-zero elements of classes ['vegetation', 'road', 'building']: 1 masks
# Cluster with 19 non-zero elements of classes ['car', 'bicycle', 'road']: 1 masks
# Cluster with 19 non-zero elements of classes ['truck', 'road', 'car']: 1 masks

# %% [markdown]
# Masks with the same class for all the pixels:

# %%
cnt = 0
for k, v in clusters_freq.items():
  if k[0] == 1:
    cnt += len(v)

print("Percentage of Masks with only 1 class:", cnt/len(masks_ids)*100)
# Out:
# Percentage of Masks with only 1 class: 43.07142542021441

# %%
cnt = 0
cnt_r = 0
for k, v in clusters_freq.items():
  if k[0] == 1:
    cnt += len(v)
    if k[1][0] == 0:
      cnt_r+= len(v)
print("Percentage of Masks with more than 1 class:", 100 - cnt/len(masks_ids)*100)
print("Percentage of Masks with only class ROAD", cnt_r/cnt*100)
# Out:
# Percentage of Masks with more than 1 class: 56.92857457978559
# Percentage of Masks with only class ROAD 99.5322476014886

# %%
# for x in clusters_freq.items():
#   print(x)

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Supponendo che 'clusters_freq' sia già stato calcolato come nel codice fornito
# Calcolo delle dimensioni di ciascun cluster
dimensioni_cluster = {k: len(v) for k, v in clusters_freq.items() if k[0] != 1}

etichette = []
valori = []

for k, v in dimensioni_cluster.items():
    descrizione = f"{k[0]} classes"
    etichette.append(descrizione)
    valori.append(v)

cluster_labels = [f"{k[0]} classes" for k in dimensioni_cluster.keys()]
frequenze = list(dimensioni_cluster.values())

sorted_indices = np.argsort(frequenze)[::-1]
cluster_labels = [cluster_labels[i] for i in sorted_indices]
frequenze = [frequenze[i] for i in sorted_indices]

plt.figure(figsize=(12, 8), dpi=150)
plt.barh(cluster_labels, frequenze, color=plt.cm.tab20.colors)
plt.xlabel("# Masks")
plt.ylabel("Groupings")
plt.title("Dataset variability")
plt.gca().invert_yaxis()
plt.show()

# %%
data = clusters_freq
k1_groups = defaultdict(list)
for (k1, k2), v in data.items():
    k1_groups[k1].append((k2, v))

# %% [markdown]
# ## Clusters statistics

# %%
output = ""
particular_k1_groups = defaultdict(list)
for k1, val in k1_groups.items():
  output += f"# Classes: {k1}\n"
  for v in val:
    nc = [mask_id for mask_id in v[1] if int(labels.iloc[mask_id]) == 0]
    err = [mask_id for mask_id in v[1] if not(int(labels.iloc[mask_id]) == 0 or int(labels.iloc[mask_id]) == 1)]
    if len(err)!=0:
       print("ERRORI")
    perc_notcrit = ((len(nc)/len(v[1])) * 100, len(nc))
    perc_crit = (100 - perc_notcrit[0], len(v[1]) - len(nc))
    if perc_notcrit[0] != 0 and perc_notcrit[0] != 100:
       particular_k1_groups[k1].append((v[0], v[1]))

    output += f"{[cityscapes_labels_dict[i]['name'] for i in v[0]]} : \n\tNON critical perc: {perc_notcrit[0]:.2f}\n\tCritical perc: {perc_crit[0]:.2f}\n"

with open("./statistics.txt", "w") as file:
    file.write(output)

# %% [markdown]
# ## Clusters visualization

# %%
groups = particular_k1_groups

k1_slider = widgets.SelectionSlider(
    options=sorted(groups.keys()),
    description="# Classi presenti",
    style={'description_width': '50px'},
    layout={'width': '500px'}
)

k2_dropdown = widgets.Dropdown(
    options={"Seleziona un valore": ([], [])},
    description="Classi più frequenti",
    style={'description_width': '50px'},
    layout={'width': '300px'}
)

v_slider = widgets.SelectionSlider(
    options=[0],
    value=0,
    description="Mask index",
    style={'description_width': '50px'},
    layout={'width': '500px'}
)

f_slider = widgets.IntSlider(
    value = 0,
    min = 0,
    max = 2,
    step = 1,
    description = "Label filter",
    style={'description_width': '50px'},
    layout={'width': '500px'}
)

def display_mask(n_el, cl, filt, mask_idx):
    frame, fault, _, _, _, mask, _ = fod_dataset[mask_idx]
    print(f"Masks percentage/number with the following characteristics: {len(v_slider.options)/total*100:.2f}/{len(v_slider.options)}")
    plt.figure(figsize=(10, 5))
    plt.imshow(get_color_pallete(mask.cpu().numpy()))
    title = "All Clusters" if filt == 0 else {"Non Critical Clusters" if filt == 1 else "Critical Clusters"}
    plt.title(f"{title} with {n_el} non-zero elements of classes: {[cityscapes_labels_dict[i]['name'] for i in cl[0]]} - Mask {(frame, fault['injection'])}")
    plt.axis('off')
    plt.show()

def update_k2_options(change):
    k1 = change['new']
    k2_options = {str(k2): (k2, v) for k2, v in groups[k1]}
    k2_dropdown.options = k2_options
    if k2_options:
        k2_dropdown.value = list(k2_options.values())[0]
        f_slider.value = 0
    else:
        k2_dropdown.value = None

def filtering_fun(filt):
    if filt == 0:
        def x(val):
            return True
        return  x
    elif filt == 1: # NON CRITICAL MASKS
        def x(val):
            return int(labels.iloc[val]) == 0
        return  x
    elif filt == 2: # CRITICAL MASKS
        def x(val):
            return int(labels.iloc[val]) == 1
        return  x
    else:
        def x(val):
            return False
        return  x

def update_v_slider(change):
    if change['new']:
        if isinstance(change['new'], tuple):
            k2, v = change['new']
        if isinstance(change['new'], int):
            filt = change['new']
            x = filtering_fun(filt)
            v = k2_dropdown.value[1]
            v = list(filter(x, v))
        if v or len(v) != 0:
            v_slider.options = v
            v_slider.value = v[0]
        else:
            v_slider.options = [0]
            v_slider.value = 0

k1_slider.observe(update_k2_options, names='value')
k2_dropdown.observe(update_v_slider, names='value')
f_slider.observe(update_v_slider, names='value')

update_k2_options({'new': k1_slider.value})
update_v_slider({'new': k2_dropdown.value})
update_v_slider({'new': f_slider.value})

ui = VBox([k1_slider, k2_dropdown, f_slider, v_slider])
out = interactive_output(display_mask, {'n_el': k1_slider, 'cl':k2_dropdown, 'filt':f_slider,  'mask_idx': v_slider})

display(ui, out)
# Out:
# VBox(children=(SelectionSlider(description='# Classi presenti', layout=Layout(width='500px'), options=(6, 7, 8…
# Output()
